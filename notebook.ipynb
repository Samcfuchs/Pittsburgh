# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_excel('data/zillow_pittsburgh.xlsx')
data.columns
# Out:
# /home/sam/miniconda3/envs/4310/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Index(['Street Address', 'City', 'State', 'Zipcode', 'Latitude', 'Longitude',
#        'Property Type', 'Tax Assessment Year', 'Tax Assessment Amt',
#        'Year Built', 'Lot Size (Sq.Ft.)', 'Finished (Sq.Ft.)', 'Bathroom',
#        'Bedrooms', 'Total Rooms', 'Last Sold Date', 'Months Since Last Sold',
#        'Last Sold Price', 'Zestimate Amount', 'Zestimate 1-Week Change',
#        'Zestimate Minimum', 'Zestimate Maximum', 'Zestimate $/Sq.Ft.',
#        'RentZestimate Amount', 'RentZestimate 1-Week Change',
#        'RentZestimate Minimum', 'RentZestimate Maximum',
#        'RentZestimate $/Sq.Ft.', 'Zestimate / Rent Value', 'Neighborhood',
#        'ZPID', 'Missing Cnt'],
#       dtype='object')

# %%
data['Property Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['Tax Assessment Year'].value_counts()
# Out:
# 2015.0    418
# 2012.0      1
# 2010.0      1
# Name: Tax Assessment Year, dtype: int64

# %%
vc = data['Year Built'].value_counts().sort_index()
plt.bar(vc.index, vc.values)
# Out:
# <BarContainer object of 105 artists>

# %%
sns.kdeplot((data['Lot Size (Sq.Ft.)']), log_scale=False)
# Out:
# <AxesSubplot:xlabel='Lot Size (Sq.Ft.)', ylabel='Density'>

# %%
numeric = data[[ 'Latitude', 'Longitude',
        'Tax Assessment Year', 'Tax Assessment Amt',
       'Year Built', 'Lot Size (Sq.Ft.)', 'Finished (Sq.Ft.)', 'Bathroom',
       'Bedrooms', 'Total Rooms',  'Months Since Last Sold',
       'Last Sold Price', 'Zestimate Amount', 'Zestimate 1-Week Change',
       'Zestimate Minimum', 'Zestimate Maximum', 'Zestimate $/Sq.Ft.',
       'RentZestimate Amount', 'RentZestimate 1-Week Change',
       'RentZestimate Minimum', 'RentZestimate Maximum',
       'RentZestimate $/Sq.Ft.', 'Zestimate / Rent Value'
]]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11346/3719241449.py in <module>
# ----> 1 sns.pairplot(data)
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2138     if kind == "scatter":
#    2139         from .relational import scatterplot  # Avoid circular import
# -> 2140         plotter(scatterplot, **plot_kws)
#    2141     elif kind == "reg":
#    2142         from .regression import regplot  # Avoid circular import
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/seaborn/axisgrid.py in map_offdiag(self, func, **kwargs)
#    1385         """
#    1386         if self.square_grid:
# -> 1387             self.map_lower(func, **kwargs)
#    1388             if not self._corner:
#    1389                 self.map_upper(func, **kwargs)
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/seaborn/axisgrid.py in map_lower(self, func, **kwargs)
#    1355         """
#    1356         indices = zip(*np.tril_indices_from(self.axes, -1))
# -> 1357         self._map_bivariate(func, indices, **kwargs)
#    1358         return self
#    1359
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/seaborn/axisgrid.py in _map_bivariate(self, func, indices, **kwargs)
#    1537             if ax is None:  # i.e. we are in corner mode
#    1538                 continue
# -> 1539             self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1540         self._add_axis_labels()
#    1541
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/seaborn/axisgrid.py in _plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1577         kwargs.setdefault("hue_order", self._hue_order)
#    1578         kwargs.setdefault("palette", self._orig_palette)
# -> 1579         func(x=x, y=y, **kwargs)
#    1580
#    1581         self._update_legend_data(ax)
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     825     p._attach(ax)
#     826
# --> 827     p.plot(ax, kwargs)
#     828
#     829     return ax
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     666
#     667         # Finalize the axes details
# --> 668         self._add_axis_labels(ax)
#     669         if self.legend:
#     670             self.add_legend_data(ax)
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/seaborn/_core.py in _add_axis_labels(self, ax, default_x, default_y)
#    1195             ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1196         if not ax.get_ylabel():
# -> 1197             y_visible = any(t.get_visible() for t in ax.get_yticklabels())
#    1198             ax.set_ylabel(self.variables.get("y", default_y), visible=y_visible)
#    1199
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      73
#      74         def wrapper(self, *args, **kwargs):
# ---> 75             return get_method(self)(*args, **kwargs)
#      76
#      77         wrapper.__module__ = owner.__module__
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1247         if minor:
#    1248             return self.get_minorticklabels()
# -> 1249         return self.get_majorticklabels()
#    1250
#    1251     def get_majorticklines(self):
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1199     def get_majorticklabels(self):
#    1200         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1201         ticks = self.get_major_ticks()
#    1202         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1203         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1369         r"""Return the list of major `.Tick`\s."""
#    1370         if numticks is None:
# -> 1371             numticks = len(self.get_majorticklocs())
#    1372
#    1373         while len(self.majorTicks) < numticks:
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1275     def get_majorticklocs(self):
#    1276         """Return this Axis' major tick locations in data coordinates."""
# -> 1277         return self.major.locator()
#    1278
#    1279     def get_minorticklocs(self):
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/ticker.py in __call__(self)
#    2111
#    2112     def __call__(self):
# -> 2113         vmin, vmax = self.axis.get_view_interval()
#    2114         return self.tick_values(vmin, vmax)
#    2115
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axis.py in getter(self)
#    1985     def getter(self):
#    1986         # docstring inherited.
# -> 1987         return getattr(getattr(self.axes, lim_name), attr_name)
#    1988
#    1989     def setter(self, vmin, vmax, ignore=False):
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axes/_base.py in viewLim(self)
#     779     @property
#     780     def viewLim(self):
# --> 781         self._unstale_viewLim()
#     782         return self._viewLim
#     783
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axes/_base.py in _unstale_viewLim(self)
#     774                 for ax in self._shared_axes[name].get_siblings(self):
#     775                     ax._stale_viewlims[name] = False
# --> 776             self.autoscale_view(**{f"scale{name}": scale
#     777                                    for name, scale in need_scale.items()})
#     778
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2933             scalex, self._autoscaleXon, self._shared_axes["x"], 'x',
#    2934             self.xaxis, self._xmargin, x_stickies, self.set_xbound)
# -> 2935         handle_single_axis(
#    2936             scaley, self._autoscaleYon, self._shared_axes["y"], 'y',
#    2937             self.yaxis, self._ymargin, y_stickies, self.set_ybound)
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axes/_base.py in handle_single_axis(scale, autoscaleon, shared_axes, name, axis, margin, stickies, set_bound)
#    2927             if not self._tight:
#    2928                 x0, x1 = locator.view_limits(x0, x1)
# -> 2929             set_bound(x0, x1)
#    2930             # End of definition of internal function 'handle_single_axis'.
#    2931
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axes/_base.py in set_ybound(self, lower, upper)
#    3902             upper = old_upper
#    3903
# -> 3904         self.set_ylim(sorted((lower, upper),
#    3905                              reverse=bool(self.yaxis_inverted())),
#    3906                       auto=None)
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axes/_base.py in set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    4059             for other in self._shared_axes["y"].get_siblings(self):
#    4060                 if other is not self:
# -> 4061                     other.set_ylim(self.viewLim.intervaly,
#    4062                                    emit=False, auto=auto)
#    4063                     if other.figure != self.figure:
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axes/_base.py in viewLim(self)
#     779     @property
#     780     def viewLim(self):
# --> 781         self._unstale_viewLim()
#     782         return self._viewLim
#     783
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axes/_base.py in _unstale_viewLim(self)
#     766         # We should arrange to store this information once per share-group
#     767         # instead of on every axis.
# --> 768         need_scale = {
#     769             name: any(ax._stale_viewlims[name]
#     770                       for ax in self._shared_axes[name].get_siblings(self))
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/axes/_base.py in <dictcomp>(.0)
#     768         need_scale = {
#     769             name: any(ax._stale_viewlims[name]
# --> 770                       for ax in self._shared_axes[name].get_siblings(self))
#     771             for name in self._axis_names}
#     772         if any(need_scale.values()):
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in get_siblings(self, a)
#     872     def get_siblings(self, a):
#     873         """Return all of the items joined with *a*, including itself."""
# --> 874         self.clean()
#     875         siblings = self._mapping.get(weakref.ref(a), [weakref.ref(a)])
#     876         return [x() for x in siblings]
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in clean(self)
#     824         """Clean dead weak references from the dictionary."""
#     825         mapping = self._mapping
# --> 826         to_drop = [key for key in mapping if key() is None]
#     827         for key in to_drop:
#     828             val = mapping.pop(key)
#
# ~/miniconda3/envs/4310/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in <listcomp>(.0)
#     824         """Clean dead weak references from the dictionary."""
#     825         mapping = self._mapping
# --> 826         to_drop = [key for key in mapping if key() is None]
#     827         for key in to_drop:
#     828             val = mapping.pop(key)
#
# KeyboardInterrupt:
